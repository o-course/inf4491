# %% [markdown]
# # Assignment 9
#
# ## Due June 26th
#
# ### names: zhang, guangde

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import linalg as LA
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.datasets import load_breast_cancer
from scipy.stats import expon
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.linear_model import LinearRegression, LogisticRegression
import networkx as nx

np.random.seed(42)

# %% [markdown]
# ## Exercise 1

# %%
X, y = load_breast_cancer(return_X_y=True)
shuffled_idx = np.random.permutation(len(X))
X, y = X[shuffled_idx], y[shuffled_idx]
len_test = len(X) // 3 * 2
X_train, X_test = X[:len_test], X[len_test:]
y_train, y_test = y[:len_test], y[len_test:]

# %%
parameters = {'C':[0.01, 0.1, 1, 10, 100],
              'gamma': [0.01, 0.1, 1, 10, 100]}

# %%
param_dist = {'C': expon(), 'gamma': expon()}

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### a)

# %%
def MDS(D, d):
    pass

# %% [markdown]
# ### b)

# %%
eurocity_dataframe = pd.read_csv('eurocity.csv', index_col=0, header=0)
eurocity_dataframe
# Out:
#                  Athens  Barcelona  Brussels  Calais  Cherbourg  Cologne  \
# Athens                0       3313      2963    3175       3339     2762
# Barcelona          3313          0      1318    1326       1294     1498
# Brussels           2963       1318         0     204        583      206
# Calais             3175       1326       204       0        460      409
# Cherbourg          3339       1294       583     460          0      785
# Cologne            2762       1498       206     409        785        0
# Copenhagen         3276       2218       966    1136       1545      760
# Geneva             2610        803       677     747        853     1662
# Gibraltar          4485       1172      2256    2224       2047     2436
# Hamburg            2977       2018       597     714       1115      460
# Hook of Holland    3030       1490       172     330        731      269
# Lisbon             4532       1305      2084    2052       1827     2290
# Lyons              2753        645       690     739        789      714
# Madrid             3949        636      1558    1550       1347     1764
# Marseilles         2865        521      1011    1059       1101     1035
# Milan              2282       1014       925    1077       1209      911
# Munich             2179       1365       747     977       1160      583
# Paris              3000       1033       285     280        340      465
# Rome                817       1460      1511    1662       1794     1497
# Stockholm          3927       2868      1616    1786       2196     1403
# Vienna             1991       1802      1175    1381       1588      937
#
#                  Copenhagen  Geneva  Gibraltar  Hamburg   ...    Lisbon  \
# Athens                 3276    2610       4485     2977   ...      4532
# Barcelona              2218     803       1172     2018   ...      1305
# Brussels                966     677       2256      597   ...      2084
# Calais                 1136     747       2224      714   ...      2052
# Cherbourg              1545     853       2047     1115   ...      1827
# Cologne                 760    1662       2436      460   ...      2290
# Copenhagen                0    1418       3196      460   ...      2971
# Geneva                 1418       0       1975     1118   ...      1936
# Gibraltar              3196    1975          0     2897   ...       676
# Hamburg                 460    1118       2897        0   ...      2671
# Hook of Holland         269     895       2428      550   ...      2280
# Lisbon                 2971    1936        676     2671   ...         0
# Lyons                  1458     158       1817     1159   ...      1178
# Madrid                 2498    1439        698     2198   ...       668
# Marseilles             1778     425       1693     1479   ...      1762
# Milan                  1537     328       2185     1238   ...      2250
# Munich                 1104     591       2565      805   ...      2507
# Paris                  1176     513       1971      877   ...      1799
# Rome                   2050     995       2631     1751   ...      2700
# Stockholm               650    2068       3886      949   ...      3231
# Vienna                 1455    1019       2974     1155   ...      2937
#
#                  Lyons  Madrid  Marseilles  Milan  Munich  Paris  Rome  \
# Athens            2753    3949        2865   2282    2179   3000   817
# Barcelona          645     636         521   1014    1365   1033  1460
# Brussels           690    1558        1011    925     747    285  1511
# Calais             739    1550        1059   1077     977    280  1662
# Cherbourg          789    1347        1101   1209    1160    340  1794
# Cologne            714    1764        1035    911     583    465  1497
# Copenhagen        1458    2498        1778   1537    1104   1176  2050
# Geneva             158    1439         425    328     591    513   995
# Gibraltar         1817     698        1693   2185    2565   1971  2631
# Hamburg           1159    2198        1479   1238     805    877  1751
# Hook of Holland    863    1730        1183   1098     851    457  1683
# Lisbon            1178     668        1762   2250    2507   1799  2700
# Lyons                0    1281         320    328     724    471  1048
# Madrid            1281       0        1157   1724    2010   1273  2097
# Marseilles         320    1157           0    618    1109    792  1011
# Milan              328    1724         618      0     331    856   586
# Munich             724    2010        1109    331       0    821   946
# Paris              471    1273         792    856     821      0  1476
# Rome              1048    2097        1011    586     946   1476     0
# Stockholm         2108    3188        2428   2187    1754   1827  2707
# Vienna            1157    2409        1363    898     428   1249  1209
#
#                  Stockholm  Vienna
# Athens                3927    1991
# Barcelona             2868    1802
# Brussels              1616    1175
# Calais                1786    1381
# Cherbourg             2196    1588
# Cologne               1403     937
# Copenhagen             650    1455
# Geneva                2068    1019
# Gibraltar             3886    2974
# Hamburg                949    1155
# Hook of Holland       1500    1205
# Lisbon                3231    2937
# Lyons                 2108    1157
# Madrid                3188    2409
# Marseilles            2428    1363
# Milan                 2187     898
# Munich                1754     428
# Paris                 1827    1249
# Rome                  2707    1209
# Stockholm                0    2105
# Vienna                2105       0
#
# [21 rows x 21 columns]

# %% [markdown]
# ### c)

# %%
train_df = pd.read_csv('USPS.csv', sep='\t',)
X = train_df.drop(['Label'], axis=1).as_matrix()
y = train_df['Label'].as_matrix()
idx = np.any([y == 0, y == 3, y == 6, y == 9], axis=0)
X = X[idx]
y = y[idx]

# %% [markdown]
# # Exercise 3)

# %% [markdown]
# ### a)

# %%
def isomap(D, k, d):
    pass

# %% [markdown]
# ### b)
